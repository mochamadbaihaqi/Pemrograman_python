# %% [markdown]
# <a href="https://colab.research.google.com/github/mochamadbaihaqi/Pemrograman_python/blob/main/Tugas_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/MyDrive/tugaspython
# Out:
# /content/drive/MyDrive/tugaspython

# %%
ls
# Out:
# 3scene@

# %%
# import the necessary packages
from keras.models import Sequential
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.optimizers import Adam
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from PIL import Image
from imutils import paths
import numpy as np
import os

# %%
# grab all image paths in the input dataset directory, then initialize
# our list of images and corresponding class labels
print("[INFO] loading images...")
imagePaths = paths.list_images("3scene")
data = []
labels = []
# Out:
# [INFO] loading images...

# %%
# loop over our input images
for imagePath in imagePaths:
	# load the input image from disk, resize it to 64x64 pixels, scale
	# the pixel intensities to the range [0, 1], and then update our
	# images list
	image = Image.open(imagePath)
	image = np.array(image.resize((64, 64))) / 255.0
	data.append(image)

	# extract the class label from the file path and update the
	# labels list
	label = imagePath.split(os.path.sep)[-2]
	labels.append(label)

# %%
# encode the labels, converting them from strings to integers
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# %%
# perform a training and testing split, using 75% of the data for
# training and 25% for evaluation
(trainX, testX, trainY, testY) = train_test_split(np.array(data),	np.array(labels), test_size=0.25)
print(trainX.shape)
print(testX.shape)
# Out:
# (711, 64, 64, 3)
# (237, 64, 64, 3)

# %%
from keras.models import Sequential
from keras.layers.core import Flatten
from keras.layers.core import Dense

model = Sequential(
    [
      Flatten(input_shape=(64*64*3,)),
      Dense(100, activation="relu", name="layer1"),
      Dense(16, activation="relu", name="layer2"),
      Dense(16, activation="relu", name="layer3"),
      Dense(3, activation="softmax", name="layer4"),
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 12288)             0
# _________________________________________________________________
# layer1 (Dense)               (None, 100)               1228900
# _________________________________________________________________
# layer2 (Dense)               (None, 16)                1616
# _________________________________________________________________
# layer3 (Dense)               (None, 16)                272
# _________________________________________________________________
# layer4 (Dense)               (None, 3)                 51
# =================================================================
# Total params: 1,230,839
# Trainable params: 1,230,839
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the model using the Adam optimizer
print("[INFO] training network...")
opt = Adam(lr=1e-3, decay=1e-3 / 50)
model.compile(loss="categorical_crossentropy", optimizer=opt,
	metrics=["accuracy"])
H = model.fit(trainX, trainY, validation_data=(testX, testY), epochs=50, batch_size=32)
# Out:
# [INFO] training network...
# Epoch 1/50
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# 21/23 [==========================>...] - ETA: 0s - loss: 1.8954 - accuracy: 0.3616WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# 23/23 [==============================] - 0s 20ms/step - loss: 1.8451 - accuracy: 0.3783 - val_loss: 0.8564 - val_accuracy: 0.5992
# Epoch 2/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.9496 - accuracy: 0.5682 - val_loss: 1.0121 - val_accuracy: 0.4852
# Epoch 3/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7783 - accuracy: 0.6484 - val_loss: 0.7395 - val_accuracy: 0.6835
# Epoch 4/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7999 - accuracy: 0.6428 - val_loss: 0.7710 - val_accuracy: 0.6624
# Epoch 5/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.6669 - accuracy: 0.7271 - val_loss: 0.6925 - val_accuracy: 0.7257
# Epoch 6/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.6149 - accuracy: 0.7722 - val_loss: 0.7370 - val_accuracy: 0.6835
# Epoch 7/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.6552 - accuracy: 0.7215 - val_loss: 0.7190 - val_accuracy: 0.6920
# Epoch 8/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.5989 - accuracy: 0.7567 - val_loss: 0.6822 - val_accuracy: 0.7300
# Epoch 9/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.6177 - accuracy: 0.7370 - val_loss: 0.6923 - val_accuracy: 0.7173
# Epoch 10/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.5487 - accuracy: 0.7975 - val_loss: 0.6902 - val_accuracy: 0.7215
# Epoch 11/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5589 - accuracy: 0.7778 - val_loss: 0.7535 - val_accuracy: 0.6920
# Epoch 12/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4853 - accuracy: 0.8017 - val_loss: 0.6974 - val_accuracy: 0.7300
# Epoch 13/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4824 - accuracy: 0.8101 - val_loss: 0.7491 - val_accuracy: 0.7342
# Epoch 14/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4944 - accuracy: 0.8200 - val_loss: 0.9573 - val_accuracy: 0.6329
# Epoch 15/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4775 - accuracy: 0.8172 - val_loss: 0.9249 - val_accuracy: 0.6540
# Epoch 16/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4393 - accuracy: 0.8481 - val_loss: 0.6858 - val_accuracy: 0.7595
# Epoch 17/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3618 - accuracy: 0.8805 - val_loss: 0.7130 - val_accuracy: 0.7300
# Epoch 18/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3931 - accuracy: 0.8537 - val_loss: 0.7202 - val_accuracy: 0.7468
# Epoch 19/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4209 - accuracy: 0.8270 - val_loss: 0.6716 - val_accuracy: 0.7679
# Epoch 20/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4479 - accuracy: 0.8214 - val_loss: 0.6900 - val_accuracy: 0.7806
# Epoch 21/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3445 - accuracy: 0.8762 - val_loss: 0.8441 - val_accuracy: 0.6878
# Epoch 22/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3595 - accuracy: 0.8495 - val_loss: 0.7777 - val_accuracy: 0.7089
# Epoch 23/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3413 - accuracy: 0.8608 - val_loss: 0.8019 - val_accuracy: 0.7300
# Epoch 24/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3085 - accuracy: 0.8889 - val_loss: 0.7066 - val_accuracy: 0.7722
# Epoch 25/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2995 - accuracy: 0.8973 - val_loss: 0.7871 - val_accuracy: 0.7215
# Epoch 26/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2930 - accuracy: 0.8973 - val_loss: 0.7643 - val_accuracy: 0.7722
# Epoch 27/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2908 - accuracy: 0.9001 - val_loss: 0.8488 - val_accuracy: 0.7553
# Epoch 28/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3214 - accuracy: 0.8734 - val_loss: 0.7545 - val_accuracy: 0.7848
# Epoch 29/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2510 - accuracy: 0.9212 - val_loss: 0.7237 - val_accuracy: 0.7722
# Epoch 30/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2788 - accuracy: 0.9001 - val_loss: 0.7871 - val_accuracy: 0.7257
# Epoch 31/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3569 - accuracy: 0.8551 - val_loss: 0.7490 - val_accuracy: 0.8059
# Epoch 32/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2753 - accuracy: 0.8889 - val_loss: 0.8315 - val_accuracy: 0.7215
# Epoch 33/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2186 - accuracy: 0.9353 - val_loss: 0.8320 - val_accuracy: 0.7384
# Epoch 34/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2492 - accuracy: 0.9255 - val_loss: 0.7719 - val_accuracy: 0.7468
# Epoch 35/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1972 - accuracy: 0.9381 - val_loss: 0.7973 - val_accuracy: 0.7679
# Epoch 36/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1821 - accuracy: 0.9409 - val_loss: 0.9707 - val_accuracy: 0.7173
# Epoch 37/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2718 - accuracy: 0.8931 - val_loss: 0.7824 - val_accuracy: 0.7848
# Epoch 38/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1854 - accuracy: 0.9353 - val_loss: 0.8654 - val_accuracy: 0.7595
# Epoch 39/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1788 - accuracy: 0.9437 - val_loss: 0.9966 - val_accuracy: 0.7215
# Epoch 40/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1797 - accuracy: 0.9367 - val_loss: 0.9386 - val_accuracy: 0.7806
# Epoch 41/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1678 - accuracy: 0.9353 - val_loss: 0.8141 - val_accuracy: 0.7679
# Epoch 42/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1991 - accuracy: 0.9283 - val_loss: 1.2492 - val_accuracy: 0.7131
# Epoch 43/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1708 - accuracy: 0.9494 - val_loss: 0.9811 - val_accuracy: 0.7806
# Epoch 44/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3111 - accuracy: 0.8720 - val_loss: 1.0872 - val_accuracy: 0.7089
# Epoch 45/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1722 - accuracy: 0.9381 - val_loss: 0.9070 - val_accuracy: 0.7679
# Epoch 46/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1483 - accuracy: 0.9522 - val_loss: 0.9207 - val_accuracy: 0.7806
# Epoch 47/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1317 - accuracy: 0.9606 - val_loss: 0.9325 - val_accuracy: 0.7806
# Epoch 48/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1634 - accuracy: 0.9423 - val_loss: 0.9911 - val_accuracy: 0.7806
# Epoch 49/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1399 - accuracy: 0.9536 - val_loss: 0.9729 - val_accuracy: 0.7426
# Epoch 50/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1932 - accuracy: 0.9156 - val_loss: 0.9612 - val_accuracy: 0.7637

# %%
import matplotlib.pyplot as plt

print(H.history.keys())
# summarize history for accuracy
plt.plot(H.history['accuracy'])
plt.plot(H.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=32)
print(classification_report(testY.argmax(axis=1),
	predictions.argmax(axis=1), target_names=lb.classes_))
# Out:
# [INFO] evaluating network...
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
#               precision    recall  f1-score   support
#
#        coast       0.79      0.76      0.77        87
#       forest       0.73      0.84      0.78        86
#      highway       0.80      0.67      0.73        64
#
#     accuracy                           0.76       237
#    macro avg       0.77      0.76      0.76       237
# weighted avg       0.77      0.76      0.76       237

# %%
model.save('nnmodel_scene')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: nnmodel_scene/assets

# %%
import cv2
import matplotlib.pyplot as plt
image1='forest_test.jpg'

# %%
img_array = cv2.imread(image1)
plt.imshow(img_array)
plt.show()
# print(type(img_array))

# %%
image_testing = Image.open('forest_test.jpg')
image_testing = np.array(image_testing.resize((64, 64))) / 255.0
image_testing.shape
# Out:
# (64, 64, 3)
